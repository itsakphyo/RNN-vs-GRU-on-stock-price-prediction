# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import logging, sys
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, SimpleRNN
# Out:
# 2024-04-12 21:53:32.743871: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-12 21:53:32.746646: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-12 21:53:32.778473: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-12 21:53:33.454267: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df = pd.read_csv('./Google_Stock_Price_Train.csv')

# %%
df['Date']=pd.to_datetime(df['Date'])
df.set_index('Date',drop=True,inplace=True)
df['Volume'] = df['Volume'].str.replace(',', '').astype(float)
df['Close'] = df['Close'].str.replace(',', '').astype(float)
df['Close'] = df.apply(lambda x: x['Close']/2 if x['Close'] > x['High'] else x['Close'], axis=1)

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.plot(df['Open'], label='Open', color='green')
ax.plot(df['High'], label='High', color='orange')
ax.plot(df['Low'],label='Low',color='blue')
ax.plot(df['Close'],label='Close',color='red')
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Price',size=15)
ax.legend()

fig.show()

# %%
predictors = ['Open', 'High', 'Low', 'Close']

# Drop all columns except predictors
df = df[predictors]

MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)

# Split data into train, validation, and test sets
split_data = np.split(df, [int(.7*len(df)), int(.85*len(df))])
# Convert data splits into NumPy arrays
train_x, valid_x, test_x = [d[predictors].to_numpy() for d in split_data]

train_x.shape, valid_x.shape, test_x.shape
# Out:
# ((880, 4), (189, 4), (189, 4))

# %%
def create_sequence(dataset):
    sequences = []
    labels = []
    for i in range(len(dataset) - 50):  # Loop until 50 elements from the end
        sequences.append(dataset[i:i+50])
        labels.append(dataset[i+50])
    return np.array(sequences), np.array(labels)

# Call the function for train, validation, and test sets
train_seq, train_label = create_sequence(train_x)
valid_seq, valid_label = create_sequence(valid_x)
test_seq, test_label = create_sequence(test_x)
train_seq.shape, train_label.shape, valid_seq.shape, valid_label.shape, test_seq.shape, test_label.shape
# Out:
# ((830, 50, 4), (830, 4), (139, 50, 4), (139, 4), (139, 50, 4), (139, 4))

# %%
model = Sequential()
model.add(SimpleRNN(units=100, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(SimpleRNN(units=50))

model.add(Dense(4))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# 2024-04-12 21:53:35.529517: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-12 21:53:35.530299: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 50, 100)        │        10,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50, 100)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 50)             │         7,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │           204 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,254 (71.30 KB)
#  Trainable params: 18,254 (71.30 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_seq, train_label, epochs=50,validation_data=(valid_seq, valid_label), verbose=1)
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1139 - mean_absolute_error: 0.2387 - val_loss: 0.0300 - val_mean_absolute_error: 0.1600
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0125 - mean_absolute_error: 0.0886 - val_loss: 0.0228 - val_mean_absolute_error: 0.1378
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064 - mean_absolute_error: 0.0639 - val_loss: 0.0215 - val_mean_absolute_error: 0.1343
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - mean_absolute_error: 0.0528 - val_loss: 0.0188 - val_mean_absolute_error: 0.1243
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mean_absolute_error: 0.0470 - val_loss: 0.0142 - val_mean_absolute_error: 0.1074
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - mean_absolute_error: 0.0439 - val_loss: 0.0116 - val_mean_absolute_error: 0.0945
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025 - mean_absolute_error: 0.0393 - val_loss: 0.0112 - val_mean_absolute_error: 0.0936
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022 - mean_absolute_error: 0.0364 - val_loss: 0.0127 - val_mean_absolute_error: 0.0963
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - mean_absolute_error: 0.0341 - val_loss: 0.0108 - val_mean_absolute_error: 0.0909
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0314 - val_loss: 0.0104 - val_mean_absolute_error: 0.0912
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mean_absolute_error: 0.0300 - val_loss: 0.0089 - val_mean_absolute_error: 0.0837
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mean_absolute_error: 0.0279 - val_loss: 0.0089 - val_mean_absolute_error: 0.0841
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mean_absolute_error: 0.0269 - val_loss: 0.0082 - val_mean_absolute_error: 0.0798
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0252 - val_loss: 0.0093 - val_mean_absolute_error: 0.0869
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mean_absolute_error: 0.0268 - val_loss: 0.0108 - val_mean_absolute_error: 0.0943
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0263 - val_loss: 0.0086 - val_mean_absolute_error: 0.0842
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9601e-04 - mean_absolute_error: 0.0232 - val_loss: 0.0093 - val_mean_absolute_error: 0.0877
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - mean_absolute_error: 0.0247 - val_loss: 0.0069 - val_mean_absolute_error: 0.0738
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2268e-04 - mean_absolute_error: 0.0224 - val_loss: 0.0071 - val_mean_absolute_error: 0.0754
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.4445e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0091 - val_mean_absolute_error: 0.0867
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3221e-04 - mean_absolute_error: 0.0224 - val_loss: 0.0077 - val_mean_absolute_error: 0.0785
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6571e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0059 - val_mean_absolute_error: 0.0673
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4350e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0076 - val_mean_absolute_error: 0.0788
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2799e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0055 - val_mean_absolute_error: 0.0654
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4230e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0052 - val_mean_absolute_error: 0.0633
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1956e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0050 - val_mean_absolute_error: 0.0615
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6253e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0051 - val_mean_absolute_error: 0.0636
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0071e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0060 - val_mean_absolute_error: 0.0693
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6136e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0057 - val_mean_absolute_error: 0.0665
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4518e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0048 - val_mean_absolute_error: 0.0598
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2187e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0059 - val_mean_absolute_error: 0.0695
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0464e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0039 - val_mean_absolute_error: 0.0543
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7758e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0045 - val_mean_absolute_error: 0.0580
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4900e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0044 - val_mean_absolute_error: 0.0573
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4992e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0042 - val_mean_absolute_error: 0.0556
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3889e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0047 - val_mean_absolute_error: 0.0602
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8823e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0053 - val_mean_absolute_error: 0.0637
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7422e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0052 - val_mean_absolute_error: 0.0640
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2713e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0042 - val_mean_absolute_error: 0.0568
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8658e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0045 - val_mean_absolute_error: 0.0585
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3309e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0053 - val_mean_absolute_error: 0.0646
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6043e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0044 - val_mean_absolute_error: 0.0583
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9974e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0039 - val_mean_absolute_error: 0.0541
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9622e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0043 - val_mean_absolute_error: 0.0583
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3414e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0047 - val_mean_absolute_error: 0.0610
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7310e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0055 - val_mean_absolute_error: 0.0671
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2332e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0056 - val_mean_absolute_error: 0.0666
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0780e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0049 - val_mean_absolute_error: 0.0623
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9345e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0054 - val_mean_absolute_error: 0.0666
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5101e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0046 - val_mean_absolute_error: 0.0602

# %%
plt.plot(history.history['loss'], label='loss', color='green')
plt.plot(history.history['mean_absolute_error'], label='mean_absolute_error', color='orange')
plt.plot(history.history['val_loss'], label='val_loss', color='blue')
plt.plot(history.history['val_mean_absolute_error'], label='val_mean_absolute_error', color='red')
plt.show()

# %%
test_predicted = model.predict(test_seq)

# Inversing scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted) 
test_inverse_label = MMS.inverse_transform(test_label)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %%
plt.plot(test_inverse_predicted[:, 3], label='Predicted', color='red')
plt.plot(test_inverse_label[:, 3], label='Actual', color='blue')

plt.ylabel('Value')
plt.title('Predicted vs Actual Close')

plt.legend()
plt.show()

# %%
test_inverse_predicted[:5]
# Out:
# array([[684.32404, 687.7493 , 691.4488 , 690.60913],
#        [687.4011 , 687.12225, 691.8297 , 689.41003],
#        [680.58997, 685.64636, 687.52655, 685.2968 ],
#        [672.2765 , 675.6736 , 681.64484, 676.52277],
#        [671.6938 , 674.6277 , 677.341  , 673.4125 ]], dtype=float32)

# %%
test_inverse_label[:5]
# Out:
# array([[719.  , 722.98, 717.31, 718.92],
#        [714.91, 716.65, 703.26, 710.36],
#        [708.65, 708.82, 688.45, 691.72],
#        [698.77, 702.48, 693.41, 693.71],
#        [698.4 , 702.77, 692.01, 695.94]])
